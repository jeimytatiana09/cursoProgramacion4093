# %%
# TALLER 1
Pregunta= input("Desea ingresar su información")
if Pregunta == "si" or Pregunta=="s" or Pregunta =="SI" or Pregunta=="yes":
  resp = "si"
  while resp == "si" or resp == "s" or resp == "SI" or resp == "yes":
      N_Identificación = input("Digite su identificación: ")
      print(N_Identificación)
      nombre_Per = input("Digite su Nombre: ")
      apellido = input("Digite su Apellido: ")
      print(nombre_Per + " " + apellido)
      Dirección = input("Cual es su dirección: ")
      print(Dirección)
      edad = float(input("Cual es su edad: "))
      print(edad)
      estado_civil = input("Cual es su estado civil: ")
      print(estado_civil)
      N_hijos = float(input("Cuantos hijos tiene: "))
      print(N_hijos)
      Estatura = input("Cual es su estatura: ")
      print(Estatura)
      dia_cont = input("Que día fue contratado: ")
      mes_contratado = input("Que mes fue contratado: ")
      año_contratado = input("Que año fue contratado: ")
      print(dia_cont + "-" + mes_contratado+"-"+año_contratado)
      Sueldo = float(input("Cual es su sueldo: "))
      print(Sueldo)
      dias = float(input("Cuantos días ha trabajado: "))
      print(dias)
      
      if edad > 55:
        descu = Sueldo * 0.15
        print("Su bono prestacional es= ${:,.0f}".format(descu))
      else:
        print("No tiene bono prestacional")
      if estado_civil == "casado" and N_hijos > 0:
        print("se le otorgará un paseo cada diciembre")
      else:
        print("No es acreedor de un paseo en Diciembre")
      if Sueldo >= 1000000 and Sueldo <= 1500000:
        comision = Sueldo * 0.02
        print("Su Comisión es de= ${:,.0f}".format(comision))
      elif Sueldo >= 1500001  and Sueldo <= 2000000:
        comision_2 = Sueldo * 0.05
        print("Su Comisión es de= ${:,.0f}".format(comision_2))
      else:
        print("No tiene comisión")
      if dias >20 and Sueldo < 1000000:
        print("Tiene derecho a un bono de alimentacion")
      else:
        print("No tiene derecho a un bono de alimentación")
        resp = input("¿Desea ingresar información nuevamente? ")
  else: 
        print("Gracias por visitarnos")
# Out:
# Desea ingresar su informaciónSI
# Digite su identificación: 1074558950
# 1074558950
# Digite su Nombre: Tatiana
# Digite su Apellido: Alvarado
# Tatiana Alvarado
# Cual es su dirección: CALLE 8#2-32
# CALLE 8#2-32
# Cual es su edad: 24
# 24.0
# Cual es su estado civil: soltera
# soltera
# Cuantos hijos tiene: 0
# 0.0
# Cual es su estatura: 170
# 170
# Que día fue contratado: 01
# Que mes fue contratado: julio
# Que año fue contratado: 2020
# 01-julio-2020
# Cual es su sueldo: 4000000
# 4000000.0
# Cuantos días ha trabajado: 700
# 700.0
# No tiene bono prestacional
# No es acreedor de un paseo en Diciembre
# No tiene comisión
# No tiene derecho a un bono de alimentación
# ¿Desea ingresar información nuevamente? s
# Digite su identificación: 28394029
# 28394029
# Digite su Nombre: Jose
# Digite su Apellido: Fernandez
# Jose Fernandez
# Cual es su dirección: Calle 187# 25-49
# Calle 187# 25-49
# Cual es su edad: 56
# 56.0
# Cual es su estado civil: casado
# casado
# ...
